# %% [markdown]
# <a href="https://colab.research.google.com/github/lfadams37/Python/blob/master/063_Zillow_For_Sale_Properties_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps
# ### Get Keys
# 1) Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#
# Store each key in a central and private location.
#
# ### Subscribe to APIs
#
# 1) Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Local & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/Colab Data/input/' # optional

############
# REQURIED #
############
city = 'winter haven'
state = 'fl'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Mounted at /content/drive
# Search string: winter haven, fl

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### Get API Keys

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key =  df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %% [markdown]
# ## <font color="green">Zillow</font>

# %% [markdown]
# ### <font color="purple">Endpoint: Property</font>

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":search_str,
               "home_type":"Houses",
               "minPrice": "100000",
               "maxPrice": "350000",
               "sqftMin": "1000"}

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': rapid_api_key
    }

z_for_sale_resp = requests.request("GET", url, headers=headers, params=querystring)

# transform to json
z_for_sale_resp_json = z_for_sale_resp.json()
z_for_sale_resp_json
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.44570707070707,
#    'address': '1001 W Lake Cannon Dr NW, Winter Haven, FL 33881',
#    'variableData': {'text': '$5,000 (Nov 3)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -5000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/80dce0645c5600666cd6f0daa0d18553-p_e.jpg',
#    'price': 234000,
#    'detailUrl': '/homedetails/1001-W-Lake-Cannon-Dr-NW-Winter-Haven-FL-33881/47366788_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.75746,
#    'latitude': 28.032701,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47366788',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1800,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1461,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8250,
#    'address': '133 Lameraux Rd, Winter Haven, FL 33884',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 286800,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/359e170f320f5a20b2dd987c90096aab-p_e.jpg',
#    'price': 287900,
#    'detailUrl': '/homedetails/133-Lameraux-Rd-Winter-Haven-FL-33884/47294584_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.66521,
#    'latitude': 27.992672,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47294584',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1849,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1656,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7440,
#    'address': '4756 Summerfield Cir, Winter Haven, FL 33881',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 303200,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/951b83a724597491e8bc619ff872bc1f-p_e.jpg',
#    'price': 304990,
#    'detailUrl': '/homedetails/4756-Summerfield-Cir-Winter-Haven-FL-33881/89576028_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.66545,
#    'latitude': 28.028847,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '89576028',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1876,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1656,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9836,
#    'address': '920 Maddox St, Winter Haven, FL 33880',
#    'variableData': {'text': '$30,000 (Sep 26)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -30000,
#    'zestimate': 291100,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/07020525346384700f8bb32c07fbe016-p_e.jpg',
#    'price': 294900,
#    'detailUrl': '/homedetails/920-Maddox-St-Winter-Haven-FL-33880/2057698271_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.77728,
#    'latitude': 27.982841,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2057698271',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1949,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1603,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5001,
#    'address': '1721 Broxey Ct NE, Winter Haven, FL 33881',
#    'variableData': {'text': '$10,000 (Oct 25)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -10000,
#    'zestimate': 130600,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5fd6a366f98fd3799a44459ef1a937bf-p_e.jpg',
#    'price': 139900,
#    'detailUrl': '/homedetails/1721-Broxey-Ct-NE-Winter-Haven-FL-33881/47376768_zpid/',
#    'bedrooms': 2,
#    'contingentListingType': None,
#    'longitude': -81.726265,
#    'latitude': 28.04031,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47376768',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1494,
#    'daysOnZillow': -1,
#    'bathrooms': 1,
#    'livingArea': 1150,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5881,
#    'address': '2300 Rose Blvd, Winter Haven, FL 33881',
#    'variableData': {'text': '$20,000 (Oct 30)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -20000,
#    'zestimate': 279500,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/94da7912d49e1ada2f3c133c127d4ff8-p_e.jpg',
#    'price': 290000,
#    'detailUrl': '/homedetails/2300-Rose-Blvd-Winter-Haven-FL-33881/95059213_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.699165,
#    'latitude': 28.039532,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '95059213',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1976,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1867,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5266,
#    'address': '2111 Kings Xing SW, Winter Haven, FL 33880',
#    'variableData': {'text': '3D Tour', 'type': '3D_HOME'},
#    'priceChange': -4000,
#    'zestimate': 247700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/622acfce2a98722fcbeaa8d804392287-p_e.jpg',
#    'price': 258000,
#    'detailUrl': '/homedetails/2111-Kings-Xing-SW-Winter-Haven-FL-33880/55134784_zpid/',
#    'bedrooms': 2,
#    'contingentListingType': None,
#    'longitude': -81.750114,
#    'latitude': 28.008467,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '55134784',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1721,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1467,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7958,
#    'address': '307 Sterling Dr, Winter Haven, FL 33884',
#    'variableData': {'text': 'Open: Sat. 12-3pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': -1,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2032469e154921d0e2433a3116cabf7c-p_e.jpg',
#    'price': 338999,
#    'detailUrl': '/homedetails/307-Sterling-Dr-Winter-Haven-FL-33884/47295352_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.67086,
#    'latitude': 27.988571,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47295352',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1444,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4200,
#    'address': '1620 Vienna Square Dr, Winter Haven, FL 33884',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d44e568a133c6cf8dd38125885a47b30-p_e.jpg',
#    'price': 249000,
#    'detailUrl': '/homedetails/1620-Vienna-Square-Dr-Winter-Haven-FL-33884/114322554_zpid/',
#    'bedrooms': 2,
#    'contingentListingType': None,
#    'longitude': -81.68558,
#    'latitude': 28.012209,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '114322554',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1377,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7701,
#    'address': '305 Vaniman Ave, Winter Haven, FL 33880',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b7f433c111ac7aba50961234c57c015a-p_e.jpg',
#    'price': 262500,
#    'detailUrl': '/homedetails/305-Vaniman-Ave-Winter-Haven-FL-33880/47392011_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.771324,
#    'latitude': 28.018814,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47392011',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1107,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.25050505050505,
#    'address': '123 Lesnick Dr, Winter Haven, FL 33880',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 276700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/94c88d20723c5543a048f81505a85c6b-p_e.jpg',
#    'price': 278900,
#    'detailUrl': '/homedetails/123-Lesnick-Dr-Winter-Haven-FL-33880/47392062_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.77109,
#    'latitude': 28.014174,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47392062',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1845,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1320,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5374,
#    'address': '2760 Whispering Trails Dr, Winter Haven, FL 33884',
#    'variableData': {'text': '$50,000 (Oct 10)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -50000,
#    'zestimate': 295500,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/8c382e14c6f2783dede44e3daf0954ce-p_e.jpg',
#    'price': 305000,
#    'detailUrl': '/homedetails/2760-Whispering-Trails-Dr-Winter-Haven-FL-33884/89579708_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.65886,
#    'latitude': 28.016764,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '89579708',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2399,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2760,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8089,
#    'address': '5807 Marsh Landing Dr, Winter Haven, FL 33881',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 296700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4b42dea961d3e53c196ea739f139289f-p_e.jpg',
#    'price': 298500,
#    'detailUrl': '/homedetails/5807-Marsh-Landing-Dr-Winter-Haven-FL-33881/98389219_zpid/',
#    'bedrooms': 2,
#    'contingentListingType': None,
#    'longitude': -81.68155,
#    'latitude': 28.057919,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '98389219',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1895,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1743,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5088,
#    'address': '3302 Timberline Rd W, Winter Haven, FL 33880',
#    'variableData': None,
#    'priceChange': 5000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e533746d934e74e81451673cb6081e1e-p_e.jpg',
#    'price': 273000,
#    'detailUrl': '/homedetails/3302-Timberline-Rd-W-Winter-Haven-FL-33880/47427388_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.78462,
#    'latitude': 28.005358,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47427388',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1517,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.50500459136823,
#    'address': '134 Sugar Creek Rd, Winter Haven, FL 33880',
#    'variableData': {'text': 'Open: Sat. 12-2pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': None,
#    'zestimate': 318300,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a6f4316a5a3268c4455259a18148285c-p_e.jpg',
#    'price': 319900,
#    'detailUrl': '/homedetails/134-Sugar-Creek-Rd-Winter-Haven-FL-33880/47402703_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.81062,
#    'latitude': 28.02164,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47402703',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 2500,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2040,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5502,
#    'address': '1186 Yumuri St, Winter Haven, FL 33884',
#    'variableData': {'text': 'Open: Sat. 8am-7:30pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': -7000,
#    'zestimate': 293000,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b5daf5fdf959941df8c916e5e69b041b-p_e.jpg',
#    'price': 302000,
#    'detailUrl': '/homedetails/1186-Yumuri-St-Winter-Haven-FL-33884/337901144_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.689255,
#    'latitude': 27.948887,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '337901144',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 2005,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1840,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8250,
#    'address': '682 Wakulla Dr SE, Winter Haven, FL 33884',
#    'variableData': {'text': 'Open: Sun. 2-4pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': -4000,
#    'zestimate': 285100,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/60648f226e84c83b1a88cbccdce335a9-p_e.jpg',
#    'price': 285000,
#    'detailUrl': '/homedetails/682-Wakulla-Dr-SE-Winter-Haven-FL-33884/55136777_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.69237,
#    'latitude': 28.007505,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '55136777',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 2299,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 1939,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.49090909090909,
#    'address': '1520 6th Ct NE, Winter Haven, FL 33881',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 283700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/78dfae042fa0dac592384461ffb6580b-p_e.jpg',
#    'price': 300000,
#    'detailUrl': '/homedetails/1520-6th-Ct-NE-Winter-Haven-FL-33881/47376352_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.71907,
#    'latitude': 28.03784,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47376352',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2125,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1915,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8830,
#    'address': '3680 Westwood Ave, Winter Haven, FL 33880',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/d60d58a5f5b8a38fe832077bf5a71249-p_e.jpg',
#    'price': 259000,
#    'detailUrl': '/homedetails/3680-Westwood-Ave-Winter-Haven-FL-33880/47387374_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.77162,
#    'latitude': 28.023693,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47387374',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1845,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 1440,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8721,
#    'address': '2201 9th Ct NE, Winter Haven, FL 33881',
#    'variableData': {'text': '$10,000 (Oct 11)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -10000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/941986fca9928b9cb7126455c9aa0a34-p_e.jpg',
#    'price': 195000,
#    'detailUrl': '/homedetails/2201-9th-Ct-NE-Winter-Haven-FL-33881/47352285_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.71357,
#    'latitude': 28.045876,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47352285',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1326,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5593,
#    'address': '5446 Chandler Dr, Winter Haven, FL 33880',
#    'variableData': {'text': '$2,400 (Nov 2)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -2400,
#    'zestimate': 342400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e1ca0cacbdc6a584175e30bfbcecfbce-p_e.jpg',
#    'price': 342500,
#    'detailUrl': '/homedetails/5446-Chandler-Dr-Winter-Haven-FL-33880/81490160_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.6611,
#    'latitude': 27.983095,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '81490160',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2299,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2836,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.27020202020202,
#    'address': '105 Suwannee Rd, Winter Haven, FL 33884',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 315900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e681c105f59a31496f5cd652b9e3f761-p_e.jpg',
#    'price': 319000,
#    'detailUrl': '/homedetails/105-Suwannee-Rd-Winter-Haven-FL-33884/55137241_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.699,
#    'latitude': 28.005526,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '55137241',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2036,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1944,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6107,
#    'address': '257 Kings Pond Ave, Winter Haven, FL 33880',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/fd0b13961ea3f261fe9f329afc68d3c7-p_e.jpg',
#    'price': 269900,
#    'detailUrl': '/homedetails/257-Kings-Pond-Ave-Winter-Haven-FL-33880/66200664_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.756195,
#    'latitude': 28.008932,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '66200664',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1417,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8451,
#    'address': '5871 Royal Hills Cir, Winter Haven, FL 33881',
#    'variableData': {'text': '$7,000 (Oct 10)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -7000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/0b52bffe4aeddf3352cc997ab21223ef-p_e.jpg',
#    'price': 315000,
#    'detailUrl': '/homedetails/5871-Royal-Hills-Cir-Winter-Haven-FL-33881/81479726_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.67676,
#    'latitude': 28.083344,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '81479726',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2194,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 2088,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5724,
#    'address': '3963 Cypress Lndg W, Winter Haven, FL 33884',
#    'variableData': {'text': '$10,000 (Oct 28)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -10000,
#    'zestimate': 259100,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5f15a6c5d59d2da5e0f769af95cce10c-p_e.jpg',
#    'price': 269900,
#    'detailUrl': '/homedetails/3963-Cypress-Lndg-W-Winter-Haven-FL-33884/47294878_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.67531,
#    'latitude': 27.992033,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47294878',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1820,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1674,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.29410009182736,
#    'address': '1311 Avenue A SE, Winter Haven, FL 33880',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 281400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/42141e9c1de5fa1248321e46f3b9d2b1-p_e.jpg',
#    'price': 290000,
#    'detailUrl': '/homedetails/1311-Avenue-A-SE-Winter-Haven-FL-33880/47397619_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.70811,
#    'latitude': 28.021505,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47397619',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1650,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1320,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5232,
#    'address': '612 Lake Dexter Cir, Winter Haven, FL 33884',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 226400,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1c530281e57e9b4886c493fbc017bc16-p_e.jpg',
#    'price': 235000,
#    'detailUrl': '/homedetails/612-Lake-Dexter-Cir-Winter-Haven-FL-33884/47300521_zpid/',
#    'bedrooms': 2,
#    'contingentListingType': None,
#    'longitude': -81.68458,
#    'latitude': 27.99554,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47300521',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1550,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1160,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9858,
#    'address': '6075 Grey Heron Dr, Winter Haven, FL 33881',
#    'variableData': {'text': '$10,000 (Nov 3)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -10000,
#    'zestimate': 270700,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4b2fb481bf17fe59838c55cb0ee9b24f-p_e.jpg',
#    'price': 280000,
#    'detailUrl': '/homedetails/6075-Grey-Heron-Dr-Winter-Haven-FL-33881/98481072_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.68098,
#    'latitude': 28.056541,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '98481072',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1949,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1767,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4600,
#    'address': '2949 Whispering Trails Dr, Winter Haven, FL 33884',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 263900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/11cb1b16f17046f52861db974c6c0972-p_e.jpg',
#    'price': 266800,
#    'detailUrl': '/homedetails/2949-Whispering-Trails-Dr-Winter-Haven-FL-33884/98398443_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.66066,
#    'latitude': 28.015718,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '98398443',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1825,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1262,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6347,
#    'address': '1073 Sawgrass Dr, Winter Haven, FL 33884',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 347900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/6992aa8f17ae35801848a897f751474b-p_e.jpg',
#    'price': 349900,
#    'detailUrl': '/homedetails/1073-Sawgrass-Dr-Winter-Haven-FL-33884/245277396_zpid/',
#    'bedrooms': 2,
#    'contingentListingType': None,
#    'longitude': -81.670685,
#    'latitude': 27.941458,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '245277396',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1949,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1514,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4356,
#    'address': '(undisclosed Address), Winter Haven, FL 33884',
#    'newConstructionType': 'BUILDER_SPEC',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c6c840c5563b86d53198c4c3c6d6e8d0-p_e.jpg',
#    'price': 298996,
#    'detailUrl': '/homedetails/Winter-Haven-FL-33884/2054585312_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': None,
#    'latitude': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2054585312',
#    'listingSubType': {'is_newHome': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1504,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5500,
#    'address': '2128 Cartgate Ln, Winter Haven, FL 33884',
#    'newConstructionType': 'BUILDER_SPEC',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/00f6c1d9fb32332dd351cf6d82a4fb9f-p_e.jpg',
#    'price': 347366,
#    'detailUrl': '/homedetails/2128-Cartgate-Ln-Winter-Haven-FL-33884/2054542310_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.69322,
#    'latitude': 27.947823,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2054542310',
#    'listingSubType': {'is_newHome': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2200,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5650,
#    'address': '516 McKenna Dr, Winter Haven, FL 33881',
#    'variableData': {'text': '3D Tour', 'type': '3D_HOME'},
#    'priceChange': -3000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/27ffee1e0a859d63d260bad7909fecfd-p_e.jpg',
#    'price': 325000,
#    'detailUrl': '/homedetails/516-McKenna-Dr-Winter-Haven-FL-33881/333281945_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.679184,
#    'latitude': 28.077408,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '333281945',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 2000,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9927,
#    'address': '309 Lake Ned Rd, Winter Haven, FL 33884',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': 284900,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ab1639607e5df97730f2e0c55a9e73ec-p_e.jpg',
#    'price': 289900,
#    'detailUrl': '/homedetails/309-Lake-Ned-Rd-Winter-Haven-FL-33884/55139200_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.671425,
#    'latitude': 27.999834,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '55139200',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1902,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1452,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5500,
#    'address': '2132 Cartgate Ln, Winter Haven, FL 33884',
#    'newConstructionType': 'BUILDER_SPEC',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3fd99b9614496faa8accfe8ddbb9a829-p_e.jpg',
#    'price': 317086,
#    'detailUrl': '/homedetails/2132-Cartgate-Ln-Winter-Haven-FL-33884/2054541779_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.69322,
#    'latitude': 27.947823,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2054541779',
#    'listingSubType': {'is_newHome': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1820,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9213,
#    'address': '971 Whisper Lake Dr, Winter Haven, FL 33880',
#    'variableData': None,
#    'priceChange': None,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/75f30f76dfab7cb8afd6ea437128a33b-p_e.jpg',
#    'price': 176000,
#    'detailUrl': '/homedetails/971-Whisper-Lake-Dr-Winter-Haven-FL-33880/47392266_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.7619,
#    'latitude': 28.011402,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47392266',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1398,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7653,
#    'address': '1614 Seth Dr, Winter Haven, FL 33880',
#    'variableData': {'text': 'Open: Sat. 12am-3pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': -10000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/812e9c66edad8868c48507087a9a85b5-p_e.jpg',
#    'price': 335000,
#    'detailUrl': '/homedetails/1614-Seth-Dr-Winter-Haven-FL-33880/2059140536_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.766655,
#    'latitude': 28.005196,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2059140536',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': None,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1850,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8433,
#    'address': '130 Ridge Ave, Winter Haven, FL 33880',
#    'variableData': {'text': '$9,000 (Nov 1)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -9000,
#    'zestimate': 299200,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cc90fb911c121ec535ca5d50e5ee4f1a-p_e.jpg',
#    'price': 290000,
#    'detailUrl': '/homedetails/130-Ridge-Ave-Winter-Haven-FL-33880/47313957_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.74848,
#    'latitude': 27.995378,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '47313957',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 1650,
#    'daysOnZillow': -1,
#    'bathrooms': 3,
#    'livingArea': 1170,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.31129476584022,
#    'address': '854 Summer Glen Dr, Winter Haven, FL 33880',
#    'variableData': {'text': 'Open: Sat. 8am-7:30pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': -4000,
#    'zestimate': 321800,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2e73414552e4a75bacddc5db04b50f7d-p_e.jpg',
#    'price': 331000,
#    'detailUrl': '/homedetails/854-Summer-Glen-Dr-Winter-Haven-FL-33880/81476694_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.76298,
#    'latitude': 28.007175,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '81476694',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 1949,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1847,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'acres',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 10781,
#    'address': '217 Majestic Gardens Ln, Winter Haven, FL 33880',
#    'variableData': {'text': '$2,000 (Nov 2)', 'type': 'PRICE_REDUCTION'},
#    'priceChange': -2000,
#    'zestimate': None,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9b239303df191a89fadfabc47ac8025c-p_e.jpg',
#    'price': 348000,
#    'detailUrl': '/homedetails/217-Majestic-Gardens-Ln-Winter-Haven-FL-33880/98408962_zpid/',
#    'bedrooms': 4,
#    'contingentListingType': None,
#    'longitude': -81.72186,
#    'latitude': 27.96636,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '98408962',
#    'listingSubType': {'is_FSBA': True},
#    'rentZestimate': 2302,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 2467,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6935,
#    'address': '1128 Brenton Manor Dr, Winter Haven, FL 33884',
#    'variableData': {'text': 'Open: Sat. 8am-7:30pm', 'type': 'OPEN_HOUSE'},
#    'priceChange': -7000,
#    'zestimate': 285100,
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5f80a412b04ff583187b1e397777ea69-p_e.jpg',
#    'price': 295000,
#    'detailUrl': '/homedetails/1128-Brenton-Manor-Dr-Winter-Haven-FL-33884/89579636_zpid/',
#    'bedrooms': 3,
#    'contingentListingType': None,
#    'longitude': -81.6525,
#    'latitude': 28.070484,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '89579636',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'rentZestimate': 1792,
#    'daysOnZillow': -1,
#    'bathrooms': 2,
#    'livingArea': 1568,
#    'country': 'USA',
#    'currency': 'USD',
#    'lotAreaUnit': 'sqft',
#    'hasImage': True}],
#  'resultsPerPage': 41,
#  'totalPages': 8,
#  'totalResultCount': 313,
#  'schools': {},
#  'currentPage': 1}

# %%
# view data
df_z_for_sale = pd.json_normalize(data=z_for_sale_resp_json['props'])
print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
df_z_for_sale.head()
# Out:
# Num of rows: 41
# Num of cols: 30
#   dateSold   propertyType  lotAreaValue  \
# 0     None  SINGLE_FAMILY      0.445707
# 1     None  SINGLE_FAMILY   8250.000000
# 2     None  SINGLE_FAMILY   7440.000000
# 3     None  SINGLE_FAMILY   9836.000000
# 4     None  SINGLE_FAMILY   5001.000000
#
#                                             address  priceChange  zestimate  \
# 0  1001 W Lake Cannon Dr NW, Winter Haven, FL 33881      -5000.0        NaN
# 1           133 Lameraux Rd, Winter Haven, FL 33884          NaN   286800.0
# 2      4756 Summerfield Cir, Winter Haven, FL 33881          NaN   303200.0
# 3             920 Maddox St, Winter Haven, FL 33880     -30000.0   291100.0
# 4         1721 Broxey Ct NE, Winter Haven, FL 33881     -10000.0   130600.0
#
#                                               imgSrc   price  \
# 0  https://photos.zillowstatic.com/fp/80dce0645c5...  234000
# 1  https://photos.zillowstatic.com/fp/359e170f320...  287900
# 2  https://photos.zillowstatic.com/fp/951b83a7245...  304990
# 3  https://photos.zillowstatic.com/fp/07020525346...  294900
# 4  https://photos.zillowstatic.com/fp/5fd6a366f98...  139900
#
#                                            detailUrl  bedrooms  \
# 0  /homedetails/1001-W-Lake-Cannon-Dr-NW-Winter-H...         3
# 1  /homedetails/133-Lameraux-Rd-Winter-Haven-FL-3...         3
# 2  /homedetails/4756-Summerfield-Cir-Winter-Haven...         3
# 3  /homedetails/920-Maddox-St-Winter-Haven-FL-338...         3
# 4  /homedetails/1721-Broxey-Ct-NE-Winter-Haven-FL...         2
#
#   contingentListingType  longitude   latitude listingStatus        zpid  \
# 0                  None -81.757460  28.032701      FOR_SALE    47366788
# 1                  None -81.665210  27.992672      FOR_SALE    47294584
# 2                  None -81.665450  28.028847      FOR_SALE    89576028
# 3                  None -81.777280  27.982841      FOR_SALE  2057698271
# 4                  None -81.726265  28.040310      FOR_SALE    47376768
#
#    rentZestimate  daysOnZillow  bathrooms  livingArea country currency  \
# 0         1800.0            -1          2        1461     USA      USD
# 1         1849.0            -1          2        1656     USA      USD
# 2         1876.0            -1          2        1656     USA      USD
# 3         1949.0            -1          2        1603     USA      USD
# 4         1494.0            -1          1        1150     USA      USD
#
#   lotAreaUnit  hasImage variableData.text variableData.type  \
# 0       acres      True    $5,000 (Nov 3)   PRICE_REDUCTION
# 1        sqft      True               NaN               NaN
# 2        sqft      True               NaN               NaN
# 3        sqft      True  $30,000 (Sep 26)   PRICE_REDUCTION
# 4        sqft      True  $10,000 (Oct 25)   PRICE_REDUCTION
#
#   listingSubType.is_FSBA  variableData listingSubType.is_openHouse  \
# 0                   True           NaN                         NaN
# 1                   True           NaN                         NaN
# 2                   True           NaN                         NaN
# 3                   True           NaN                         NaN
# 4                   True           NaN                         NaN
#
#   newConstructionType listingSubType.is_newHome
# 0                 NaN                       NaN
# 1                 NaN                       NaN
# 2                 NaN                       NaN
# 3                 NaN                       NaN
# 4                 NaN                       NaN

# %%
# download file

# %%
# get zpids to a list
zpid_list = df_z_for_sale['zpid'].tolist()
zpid_list
# Out:
# ['47366788',
#  '47294584',
#  '89576028',
#  '2057698271',
#  '47376768',
#  '95059213',
#  '55134784',
#  '47295352',
#  '114322554',
#  '47392011',
#  '47392062',
#  '89579708',
#  '98389219',
#  '47427388',
#  '47402703',
#  '337901144',
#  '55136777',
#  '47376352',
#  '47387374',
#  '47352285',
#  '81490160',
#  '55137241',
#  '66200664',
#  '81479726',
#  '47294878',
#  '47397619',
#  '47300521',
#  '98481072',
#  '98398443',
#  '245277396',
#  '2054585312',
#  '2054542310',
#  '333281945',
#  '55139200',
#  '2054541779',
#  '47392266',
#  '2059140536',
#  '47313957',
#  '81476694',
#  '98408962',
#  '89579636']

# %%
# get property detail

# create empty list
prop_detail_list = []

# iterate through list of properties
for zpid in zpid_list:

  # end point
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid}

  # header
  headers = {
      'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
      'x-rapidapi-key': rapid_api_key
      }

  # get property detail
  z_prop_detail_resp = requests.request("GET", url, headers=headers, params=querystring)
  z_prop_detail_resp_json = z_prop_detail_resp.json()

  # wait 1 sec based on limit
  time.sleep(1.5)

  prop_detail_list.append(z_prop_detail_resp_json)

# %%
# convert to dataframe
df_z_prop_detail = pd.json_normalize(prop_detail_list)
print('Num of rows:', len(df_z_prop_detail))
print('Num of cols:', len(df_z_prop_detail.columns))
df_z_prop_detail.head(2)
# Out:
# Num of rows: 41
# Num of cols: 293
#    listingProvider        zpid  buildingPermits  propertyTaxRate  \
# 0              NaN  47366788.0              NaN             0.74
# 1              NaN  47294584.0              NaN             0.74
#
#                                   contact_recipients zipcode  longitude  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   33881  -81.75746
# 1  [{'agent_reason': 1, 'zpro': None, 'recent_sal...   33884  -81.66521
#
#   zestimateLowPercent   cityId timeOnZillow  \
# 0                None  27992.0      23 days
# 1                   5  27992.0       5 days
#
#                                                  url  zestimate  \
# 0  /homedetails/1001-W-Lake-Cannon-Dr-NW-Winter-H...        NaN
# 1  /homedetails/133-Lameraux-Rd-Winter-Haven-FL-3...   286800.0
#
#                                               imgSrc  \
# 0  https://photos.zillowstatic.com/fp/80dce0645c5...
# 1  https://photos.zillowstatic.com/fp/359e170f320...
#
#                                          description     price  \
# 0  Excellent home with a view of Lake Cannon. Ima...  234000.0
# 1  Explore this impeccable well-maintained and mo...  287900.0
#
#    livingAreaValue                                         taxHistory  \
# 0           1461.0  [{'time': 1667580776982, 'valueIncreaseRate': ...
# 1           1656.0  [{'time': 1667580780717, 'valueIncreaseRate': ...
#
#    brokerId  stateId             streetAddress  solarPotential  dateSold  \
# 0       NaN     14.0  1001 W Lake Cannon Dr NW             NaN       NaN
# 1       NaN     14.0           133 Lameraux Rd             NaN       NaN
#
#    countyId          timeZone       homeType livingAreaUnits  \
# 0       NaN  America/New_York  SINGLE_FAMILY            sqft
# 1       NaN  America/New_York  SINGLE_FAMILY            sqft
#
#    comingSoonOnMarketDate  rentZestimate  bathrooms  \
# 0                     NaN         1800.0        2.0
# 1                     NaN         1849.0        2.0
#
#    annualHomeownersInsurance state propertyTypeDimension  building  yearBuilt  \
# 0                      983.0    FL         Single Family       NaN     1951.0
# 1                     1209.0    FL         Single Family       NaN     1978.0
#
#                       brokerageName  pageViewCount       county  \
# 0  Keller Williams Realty New Tampa         5725.0  Polk County
# 1       Star Realty Of Winter Haven         1230.0  Polk County
#
#    monthlyHoaFee homeStatus  homeFacts   latitude  datePosted  bedrooms  \
# 0            NaN   FOR_SALE        NaN  28.032701  2023-10-11       3.0
# 1            NaN   FOR_SALE        NaN  27.992672  2023-10-30       3.0
#
#                                          nearbyHomes  livingArea  \
# 0  [{'miniCardPhotos': [{'url': 'https://photos.z...      1461.0
# 1  [{'miniCardPhotos': [{'url': 'https://photos.z...      1656.0
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': -0.02092050209205, 'date'...          408.0
# 1  [{'priceChangeRate': 1.086231884058, 'date': '...           81.0
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/florid...                 None
# 1  [{'link': 'https://www.greatschools.org/florid...                    5
#
#       mlsid countyFIPS          city  providerListingID country currency  \
# 0  T3461890      12105  Winter Haven                NaN     USA      USD
# 1  P4927911      12105  Winter Haven                NaN     USA      USD
#
#    isListedByOwner  contingentListingType  address.community  address.city  \
# 0              NaN                    NaN                NaN  Winter Haven
# 1              NaN                    NaN                NaN  Winter Haven
#
#   address.state  address.neighborhood  address.subdivision  \
# 0            FL                   NaN                  NaN
# 1            FL                   NaN                  NaN
#
#       address.streetAddress address.zipcode resoFacts.hasAttachedProperty  \
# 0  1001 W Lake Cannon Dr NW           33881                         False
# 1           133 Lameraux Rd           33884                         False
#
#    resoFacts.frontageType resoFacts.poolFeatures  \
# 0                     NaN                   None
# 1                     NaN                   None
#
#                 resoFacts.flooring  resoFacts.builderModel  \
# 0  [Ceramic Tile, Linoleum, Other]                     NaN
# 1                   [Ceramic Tile]                     NaN
#
#   resoFacts.accessibilityFeatures resoFacts.hasGarage  \
# 0                            None                True
# 1                            None                True
#
#   resoFacts.hasPetsAllowed  resoFacts.bodyType  resoFacts.topography  \
# 0                     True                 NaN                   NaN
# 1                     True                 NaN                   NaN
#
#    resoFacts.landLeaseExpirationDate resoFacts.hasAdditionalParcels  \
# 0                                NaN                          False
# 1                                NaN                          False
#
#   resoFacts.waterViewYN  resoFacts.totalActualRent  resoFacts.offerReviewDate  \
# 0                  True                    22800.0                        NaN
# 1                 False                        0.0                        NaN
#
#    resoFacts.horseYN resoFacts.view resoFacts.buyerAgencyCompensationType  \
# 0                NaN  [Water, Lake]                         See Remarks:
# 1                NaN            NaN                         See Remarks:
#
#    resoFacts.belowGradeFinishedArea  \
# 0                               NaN
# 1                               NaN
#
#                                resoFacts.feesAndDues resoFacts.cityRegion  \
# 0  [{'phone': None, 'name': None, 'fee': None, 't...         Winter Haven
# 1  [{'phone': None, 'name': None, 'fee': None, 't...         Winter Haven
#
#    resoFacts.mainLevelBathrooms resoFacts.hasPrivatePool  \
# 0                           NaN                     None
# 1                           NaN                     None
#
#   resoFacts.associationFeeIncludes resoFacts.waterSource  \
# 0                             None              [Public]
# 1                             None              [Public]
#
#    resoFacts.carportParkingCapacity  resoFacts.inclusions  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
#
#   resoFacts.hasFireplace  resoFacts.gas resoFacts.sewer  \
# 0                  False            NaN  [Public Sewer]
# 1                   True            NaN  [Public Sewer]
#
#    resoFacts.elevationUnits resoFacts.roadSurfaceType  \
# 0                       NaN                [Concrete]
# 1                       NaN          [Asphalt, Paved]
#
#   resoFacts.subdivisionName  resoFacts.numberOfUnitsVacant  \
# 0                    Inwood                            NaN
# 1    Garden Grove South Add                            NaN
#
#   resoFacts.hasWaterfrontView  resoFacts.bathroomsOneQuarter  \
# 0                        None                            NaN
# 1                        None                            NaN
#
#   resoFacts.lotSize  resoFacts.entryLevel  \
# 0        0.45 Acres                   NaN
# 1        8,250 sqft                   NaN
#
#    resoFacts.irrigationWaterRightsAcres  resoFacts.greenWaterConservation  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
#
#    resoFacts.stories  resoFacts.bathrooms  resoFacts.numberOfUnitsInCommunity  \
# 0                1.0                  2.0                                 NaN
# 1                1.0                  2.0                                 NaN
#
#    resoFacts.listingTerms      resoFacts.otherParking  \
# 0                     NaN                        None
# 1                     NaN  [Garage Dimensions: 23x21]
#
#   resoFacts.associationFee  resoFacts.marketingType  \
# 0                     None                      NaN
# 1                     None                      NaN
#
#    resoFacts.greenIndoorAirQuality  resoFacts.greenSustainability  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
#
#      resoFacts.heating  resoFacts.associationPhone  \
# 0            [Central]                         NaN
# 1  [Central, Electric]                         NaN
#
#    resoFacts.greenBuildingVerificationType resoFacts.hasAttachedGarage  \
# 0                                      NaN                        True
# 1                                      NaN                        True
#
#    resoFacts.bedrooms resoFacts.architecturalStyle  resoFacts.listingId  \
# 0                 3.0                         None                  NaN
# 1                 3.0                         None                  NaN
#
#    resoFacts.structureType                         resoFacts.interiorFeatures  \
# 0                      NaN  [Built-in Features, Ceiling Fan(s), Open Floor...
# 1                      NaN  [Ceiling Fan(s), Crown Molding, Eating Space I...
#
#    resoFacts.horseAmenities  resoFacts.electric resoFacts.lotFeatures  \
# 0                       NaN                 NaN                  None
# 1                       NaN                 NaN                  None
#
#   resoFacts.roofType resoFacts.constructionMaterials  \
# 0              Other                         [Block]
# 1            Shingle                 [Block, Stucco]
#
#   resoFacts.fireplaceFeatures resoFacts.hoaFeeTotal  resoFacts.doorFeatures  \
# 0                        None                  None                     NaN
# 1               [Family Room]                  None                     NaN
#
#    resoFacts.taxAnnualAmount  resoFacts.bathroomsPartial  \
# 0                     1732.0                         NaN
# 1                     2130.0                         NaN
#
#    resoFacts.bathroomsHalf  resoFacts.daysOnZillow  resoFacts.listAOR  \
# 0                      1.0                    23.0                NaN
# 1                      0.0                     5.0                NaN
#
#    resoFacts.buildingName                                    resoFacts.attic  \
# 0                     NaN  Built in Features, Ceiling Fans(s), Open Floor...
# 1                     NaN  Ceiling Fans(s), Crown Molding, Eating Space I...
#
#    resoFacts.mainLevelBedrooms resoFacts.elementarySchool  \
# 0                          NaN                       None
# 1                          NaN          Garden Grove Elem
#
#                                resoFacts.virtualTour resoFacts.hasCarport  \
# 0  https://www.propertypanorama.com/instaview/ste...                False
# 1  https://www.propertypanorama.com/instaview/ste...                False
#
#   resoFacts.canRaiseHorses resoFacts.hasLandLease resoFacts.communityFeatures  \
# 0                    False                  False                        None
# 1                    False                  False                        None
#
#    resoFacts.yearBuiltEffective resoFacts.middleOrJuniorSchool  \
# 0                           NaN                           None
# 1                           NaN                 Denison Middle
#
#   resoFacts.lotSizeDimensions resoFacts.hasHomeWarranty  \
# 0                   130 x 150                     False
# 1                    110 x 75                     False
#
#    resoFacts.entryLocation  resoFacts.yearBuilt  resoFacts.propertySubType  \
# 0                      NaN               1951.0  [Single Family Residence]
# 1                      NaN               1978.0  [Single Family Residence]
#
#    resoFacts.propertyCondition                       resoFacts.utilities  \
# 0                          NaN  [Cable Connected, Electricity Connected]
# 1                          NaN  [Cable Available, Electricity Available]
#
#   resoFacts.parcelNumber  resoFacts.incomeIncludes resoFacts.highSchool  \
# 0     262819553671000500                       NaN                 None
# 1     262901663520001150                       NaN  Winter Haven Senior
#
#   resoFacts.isNewConstruction resoFacts.otherStructures resoFacts.livingArea  \
# 0                       False                  [Gazebo]           1,461 sqft
# 1                       False                      None           1,656 sqft
#
#    resoFacts.livingAreaRangeUnits resoFacts.buildingArea  \
# 0                             NaN                  2,076
# 1                             NaN                  2,139
#
#   resoFacts.windowFeatures resoFacts.ownership  resoFacts.woodedArea  \
# 0                     None          Fee Simple                   NaN
# 1                 [Blinds]          Fee Simple                   NaN
#
#    resoFacts.middleOrJuniorSchoolDistrict  resoFacts.associationPhone2  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
#
#   resoFacts.isSeniorCommunity resoFacts.foundationDetails  \
# 0                        None                      [Slab]
# 1                        None                         NaN
#
#   resoFacts.frontageLength resoFacts.exteriorFeatures  \
# 0                     None                    [Other]
# 1                     None            [Sliding Doors]
#
#   resoFacts.associationAmenities  resoFacts.buildingFeatures  \
# 0                           None                         NaN
# 1                           None                         NaN
#
#   resoFacts.hasCooling  resoFacts.buildingAreaSource  \
# 0                 True                           NaN
# 1                 True                           NaN
#
#                    resoFacts.parkingFeatures  resoFacts.foundationArea  \
# 0                        [Garage - Attached]                       NaN
# 1  [Driveway, Garage Door Opener, Oversized]                       NaN
#
#   resoFacts.zoning resoFacts.hoaFee  resoFacts.livingAreaRange  \
# 0              R-2             None                        NaN
# 1             None             None                        NaN
#
#    resoFacts.bathroomsFull  resoFacts.additionalParcelsDescription  \
# 0                      1.0                                     NaN
# 1                      2.0                                     NaN
#
#    resoFacts.waterBodyName resoFacts.waterfrontFeatures  \
# 0                      NaN                         None
# 1                      NaN                         None
#
#    resoFacts.aboveGradeFinishedArea  resoFacts.zoningDescription  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
#
#   resoFacts.levels resoFacts.basementYN resoFacts.hasView  \
# 0              One                False              True
# 1              One                False             False
#
#                            resoFacts.appliances  resoFacts.securityFeatures  \
# 0                                [Refrigerator]                         NaN
# 1  [Dishwasher, Microwave, Range, Refrigerator]                         NaN
#
#    resoFacts.elevation resoFacts.fencing  resoFacts.greenEnergyEfficient  \
# 0                  NaN              None                             NaN
# 1                  NaN             Vinyl                             NaN
#
#    resoFacts.developmentStatus  resoFacts.ownershipType  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
#
#    resoFacts.garageParkingCapacity resoFacts.waterView  \
# 0                              2.0          Water,Lake
# 1                              2.0                None
#
#   resoFacts.laundryFeatures resoFacts.buyerAgencyCompensation  \
# 0               [In Garage]                         3.5%-$300
# 1    [Inside, Laundry Room]                         2.5%-$495
#
#    resoFacts.basement  resoFacts.additionalFeeInfo  resoFacts.commonWalls  \
# 0                 NaN                          NaN                    NaN
# 1                 NaN                          NaN                    NaN
#
#   resoFacts.homeType resoFacts.spaFeatures  resoFacts.municipality  \
# 0       SingleFamily                  None                     NaN
# 1       SingleFamily                  None                     NaN
#
#    resoFacts.bathroomsThreeQuarter resoFacts.hasSpa resoFacts.hasHeating  \
# 0                              NaN            False                 True
# 1                              NaN            False                 True
#
#    resoFacts.associationFee2 resoFacts.cooling  resoFacts.openParkingCapacity  \
# 0                        NaN     [Central Air]                            NaN
# 1                        NaN     [Central Air]                            NaN
#
#    resoFacts.associationName2  resoFacts.hasRentControl  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
#
#    resoFacts.elementarySchoolDistrict  resoFacts.otherEquipment  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
#
#    resoFacts.associationName resoFacts.specialListingConditions  \
# 0                        NaN                               None
# 1                        NaN                               None
#
#   resoFacts.furnished  resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0               False                   NaN                            None
# 1               False                   NaN          [Rear Porch, Screened]
#
#    resoFacts.bathroomsFloat  resoFacts.builderName  \
# 0                       2.0                    NaN
# 1                       2.0                    NaN
#
#    resoFacts.highSchoolDistrict  resoFacts.exclusions  resoFacts.storiesTotal  \
# 0                           NaN                   NaN                     1.0
# 1                           NaN                   NaN                     NaN
#
#    resoFacts.landLeaseAmount  resoFacts.fireplaces  \
# 0                        NaN                   NaN
# 1                        NaN                   NaN
#
#    resoFacts.availabilityDate  resoFacts.cropsIncludedYN  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
#
#    resoFacts.coveredParkingCapacity  resoFacts.irrigationWaterRightsYN  \
# 0                               2.0                                NaN
# 1                               2.0                                NaN
#
#   resoFacts.hasOpenParking  resoFacts.onMarketDate  \
# 0                    False            1.690502e+12
# 1                     True            1.698624e+12
#
#   resoFacts.hasElectricOnProperty  resoFacts.parkingCapacity  \
# 0                            True                        2.0
# 1                            None                        2.0
#
#    resoFacts.pricePerSquareFoot  \
# 0                         160.0
# 1                         174.0
#
#                             resoFacts.atAGlanceFacts resoFacts.hasAssociation  \
# 0  [{'factValue': 'Single Family Residence', 'fac...                    False
# 1  [{'factValue': 'Single Family Residence', 'fac...                    False
#
#   listingSubType.is_FSBA listingSubType.is_comingSoon  \
# 0                   True                        False
# 1                   True                        False
#
#   listingSubType.is_newHome listingSubType.is_pending  \
# 0                     False                     False
# 1                     False                     False
#
#   listingSubType.is_forAuction listingSubType.is_foreclosure  \
# 0                        False                         False
# 1                        False                         False
#
#   listingSubType.is_bankOwned listingSubType.is_openHouse  \
# 0                       False                       False
# 1                       False                       False
#
#   listingSubType.is_FSBO  listed_by.agent_reason listed_by.zpro  \
# 0                  False                     3.0          False
# 1                  False                     NaN           None
#
#    listed_by.recent_sales           listed_by.zuid  listed_by.review_count  \
# 0                     1.0  X1-ZUwgskep8wknpl_5i26a                    62.0
# 1                     NaN                     None                     NaN
#
#   listed_by.display_name                             listed_by.profile_url  \
# 0              Paul Farr  https://www.zillow.com/profile/listwithpaulfarr/
# 1                   None                                               NaN
#
#             listed_by.business_name  listed_by.rating_average  \
# 0  Keller Williams Realty New Tampa                       5.0
# 1                              None                       NaN
#
#   listed_by.phone.prefix listed_by.phone.areacode listed_by.phone.number  \
# 0                    328                      813                   5997
# 1                    NaN                      NaN                    NaN
#
#   listed_by.badge_type                                listed_by.image_url  \
# 0        Listing Agent  https://photos.zillowstatic.com/h_n/ISu4b0588w...
# 1                 None                                               None
#
#    mortgageRates.thirtyYearFixedRate  attributionInfo.buyerAgentName  \
# 0                                NaN                             NaN
# 1                              7.266                             NaN
#
#   attributionInfo.mlsName  attributionInfo.coAgentLicenseNumber  \
# 0    Stellar MLS / MFRMLS                                   NaN
# 1    Stellar MLS / MFRMLS                                   NaN
#
#                       attributionInfo.listingOffices  \
# 0  [{'associatedOfficeType': 'listOffice', 'offic...
# 1  [{'associatedOfficeType': 'listOffice', 'offic...
#
#   attributionInfo.lastUpdated  attributionInfo.buyerAgentMemberStateLicense  \
# 0         2023-11-03 14:41:31                                           NaN
# 1         2023-10-30 14:54:20                                           NaN
#
#          attributionInfo.brokerName  attributionInfo.listingAgreement  \
# 0  Keller Williams Realty New Tampa                               NaN
# 1       Star Realty Of Winter Haven                               NaN
#
#                         attributionInfo.infoString10  \
# 0  IDX information is provided exclusively for pe...
# 1  IDX information is provided exclusively for pe...
#
#    attributionInfo.trueStatus  \
# 0                         NaN
# 1                         NaN
#
#                          attributionInfo.infoString3  \
# 0  https://photos.zillowstatic.com/fp/e39375731b4...
# 1  https://photos.zillowstatic.com/fp/e39375731b4...
#
#    attributionInfo.agentEmail attributionInfo.agentName  \
# 0                         NaN                 Paul Farr
# 1                         NaN          CarLee Marchetti
#
#   attributionInfo.attributionTitle attributionInfo.mlsId  \
# 0             Listing Provided by:              T3461890
# 1             Listing Provided by:              P4927911
#
#   attributionInfo.coAgentName attributionInfo.coAgentNumber  \
# 0                        None                          None
# 1              John Marchetti                  863-581-1338
#
#   attributionInfo.infoString5  \
# 0                813-842-5408
# 1                863-258-3338
#
#                        attributionInfo.listingAgents  \
# 0  [{'memberStateLicense': '3356486', 'memberFull...
# 1  [{'memberStateLicense': '3476536', 'memberFull...
#
#   attributionInfo.agentPhoneNumber  attributionInfo.agentLicenseNumber  \
# 0                     813-842-5408                                 NaN
# 1                     863-258-3338                                 NaN
#
#                         attributionInfo.providerLogo  \
# 0  https://photos.zillowstatic.com/fp/e39375731b4...
# 1  https://photos.zillowstatic.com/fp/e39375731b4...
#
#    attributionInfo.infoString16  attributionInfo.buyerBrokerageName  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
#
#                        attributionInfo.mlsDisclaimer  \
# 0  IDX information is provided exclusively for pe...
# 1  IDX information is provided exclusively for pe...
#
#   attributionInfo.brokerPhoneNumber attributionInfo.lastChecked  \
# 0                      813-994-4422         2023-11-04 09:38:21
# 1                      863-299-7827         2023-11-04 09:38:21
#
#    listed_by.phone resoFacts.associations openHouseSchedule message
# 0              NaN                    NaN               NaN     NaN
# 1              NaN                    NaN               NaN     NaN

# %%
# columns of interest
detail_cols = ['streetAddress',
 'city',
 'county',
 'zipcode',
 'state',
 'price',
 'homeType',
 'timeOnZillow',
 'zestimate',
 'rentZestimate',
 'livingArea',
 'bedrooms',
 'bathrooms',
 'yearBuilt',
 'description',
 'priceHistory',
 'taxHistory',
 'zpid'
 ]

# retain limited columns for output
df_z_prop_detail_output = df_z_prop_detail[detail_cols]
df_z_prop_detail_output.head()
# Out:
#               streetAddress          city       county zipcode state  \
# 0  1001 W Lake Cannon Dr NW  Winter Haven  Polk County   33881    FL
# 1           133 Lameraux Rd  Winter Haven  Polk County   33884    FL
# 2      4756 Summerfield Cir  Winter Haven  Polk County   33881    FL
# 3             920 Maddox St  Winter Haven  Polk County   33880    FL
# 4         1721 Broxey Ct NE  Winter Haven  Polk County   33881    FL
#
#       price       homeType timeOnZillow  zestimate  rentZestimate  livingArea  \
# 0  234000.0  SINGLE_FAMILY      23 days        NaN         1800.0      1461.0
# 1  287900.0  SINGLE_FAMILY       5 days   286800.0         1849.0      1656.0
# 2  304990.0  SINGLE_FAMILY      3 hours   303200.0         1876.0      1656.0
# 3  294900.0  SINGLE_FAMILY     170 days   291100.0         1949.0      1603.0
# 4  139900.0  SINGLE_FAMILY     100 days   130600.0         1494.0      1150.0
#
#    bedrooms  bathrooms  yearBuilt  \
# 0       3.0        2.0     1951.0
# 1       3.0        2.0     1978.0
# 2       3.0        2.0     2008.0
# 3       3.0        2.0     2022.0
# 4       2.0        1.0     1950.0
#
#                                          description  \
# 0  Excellent home with a view of Lake Cannon. Ima...
# 1  Explore this impeccable well-maintained and mo...
# 2  Come FAST! Beautiful home located in Country C...
# 3  Short Sale.  SHORT SALE. This turn-key home wa...
# 4  Welcome to the heart of Winter Haven. This cha...
#
#                                         priceHistory  \
# 0  [{'priceChangeRate': -0.02092050209205, 'date'...
# 1  [{'priceChangeRate': 1.086231884058, 'date': '...
# 2  [{'priceChangeRate': 1.0496639784946, 'date': ...
# 3  [{'priceChangeRate': -0.092336103416436, 'date...
# 4  [{'priceChangeRate': -0.066711140760507, 'date...
#
#                                           taxHistory          zpid
# 0  [{'time': 1667580776982, 'valueIncreaseRate': ...  4.736679e+07
# 1  [{'time': 1667580780717, 'valueIncreaseRate': ...  4.729458e+07
# 2  [{'time': 1667580784224, 'valueIncreaseRate': ...  8.957603e+07
# 3                                                NaN  2.057698e+09
# 4  [{'time': 1667580791206, 'valueIncreaseRate': ...  4.737677e+07

# %%
# download file
df_z_prop_detail_output.to_csv('df_z_prop_detail_output.csv')
files.download('df_z_prop_detail_output.csv')

# %% [markdown]
# ## Zillow ZPID
# Useful to retrieve zillow detailed data for ANY address

# %%
# !pip install python-zillow -q

# %%
# list of addresses
address_dict = {
    'address': [
                '125 Lithia Pinecrest Rd, Brandon, FL',
                '705 Westwood Ln, Brandon, FL',
                '101 Ruby Cir, Brandon, FL '],
    'postal_code': [
                    33511,
                    33511,
                    33510]
}
df_addresses = pd.DataFrame(data=address_dict)
df_addresses
# Out:
#                                 address  postal_code
# 0  125 Lithia Pinecrest Rd, Brandon, FL        33511
# 1          705 Westwood Ln, Brandon, FL        33511
# 2            101 Ruby Cir, Brandon, FL         33510

# %%
zillow_api_key = df_api_keys.loc[df_api_keys['API'] =='zillow']['KEY'].iloc[0] # replace this with your own key

# %%
import zillow

# create api instance
zillow_api = zillow.ValuationApi()

# create empty list
zpid_list = []

# iterate through dataframe
for index, row in df_addresses.iterrows():
  # get values to pass through api
  _address = row['address']
  _postal_code = row['postal_code']
  print(_address, _postal_code)

  # get search results
  _search_results = zillow_api.GetSearchResults(zillow_api_key, _address, _postal_code)

  # append zpid
  zpid_list.append(_search_results.zpid)
# Out:
# 125 Lithia Pinecrest Rd, Brandon, FL 33511
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# <ipython-input-24-9e878041af8c> in <module>()
#      15
#      16   # get search results
# ---> 17   _search_results = zillow_api.GetSearchResults(zillow_api_key, _address, _postal_code)
#      18
#      19   # append zpid
#
# /usr/local/lib/python3.7/dist-packages/zillow/api.py in GetSearchResults(self, zws_id, address, citystatezip, retnzestimate)
#      58         data = resp.content.decode('utf-8')
#      59
# ---> 60         xmltodict_data = xmltodict.parse(data)
#      61
#      62         place = Place()
#
# /usr/local/lib/python3.7/dist-packages/xmltodict.py in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, **kwargs)
#     325         parser.ParseFile(xml_input)
#     326     else:
# --> 327         parser.Parse(xml_input, True)
#     328     return handler.item
#     329
#
# ExpatError: not well-formed (invalid token): line 32, column 38

# %%
df_addresses['zpid'] = zpid_list
df_addresses

# %%
# get property detail

# create empty list
prop_detail_list = []

# iterate through list of properties
for zpid in zpid_list:

  # end point
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid}

  # header
  headers = {
      'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
      'x-rapidapi-key': rapid_api_key
      }

  # get property detail
  z_prop_detail_resp = requests.request("GET", url, headers=headers, params=querystring)
  z_prop_detail_resp_json = z_prop_detail_resp.json()

  # wait 1 sec based on limit
  time.sleep(1.5)

  prop_detail_list.append(z_prop_detail_resp_json)

# %%
# convert to dataframe
df_z_prop_detail = pd.json_normalize(prop_detail_list)
print('Num of rows:', len(df_z_prop_detail))
print('Num of cols:', len(df_z_prop_detail.columns))
df_z_prop_detail.head(2)

# %%
# columns of interest
detail_cols = ['streetAddress',
 'city',
 'county',
 'zipcode',
 'state',
 'price',
 'homeType',
 'timeOnZillow',
 'zestimate',
 'rentZestimate',
 'livingArea',
 'bedrooms',
 'bathrooms',
 'yearBuilt',
 'description',
 'priceHistory',
 'taxHistory',
 'zpid'
 ]

# retain limited columns for output
df_z_prop_detail_output = df_z_prop_detail[detail_cols]
df_z_prop_detail_output.head()

# %% [markdown]
# # End Notebook
